# %%
import sys
print(f"Python: {sys.executable}")
print("Installing packages...")

# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install torch torchvision --index-url https://download.pytorch.org/whl/cpu
# !{sys.executable} -m pip install numpy  pandas matplotlib seaborn scikit-learn tqdm pillow jupyter

print("\n✅ All packages installed successfully!")
# Out:
# Python: C:\Users\Professional\.conda\envs\kursach_env\python.exe
# Installing packages...
# Requirement already satisfied: pip in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (26.0.1)
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (2.1.0+cu118)
# Requirement already satisfied: torchvision in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (0.16.0+cu118)
# Requirement already satisfied: filelock in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: numpy in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from torchvision) (10.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from requests->torchvision) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from requests->torchvision) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (1.23.5)
# Requirement already satisfied: pandas in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (3.7.1)
# Requirement already satisfied: seaborn in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (0.12.2)
# Requirement already satisfied: scikit-learn in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (1.3.0)
# Requirement already satisfied: tqdm in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (4.66.1)
# Requirement already satisfied: pillow in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (10.1.0)
# Requirement already satisfied: jupyter in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from matplotlib) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: colorama in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: notebook in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter) (7.0.6)
# Requirement already satisfied: qtconsole in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter) (5.7.0)
# Requirement already satisfied: jupyter-console in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter) (7.17.0)
# Requirement already satisfied: ipykernel in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter) (6.31.0)
# Requirement already satisfied: ipywidgets in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter) (8.1.8)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipykernel->jupyter) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipykernel->jupyter) (8.12.3)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipykernel->jupyter) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipykernel->jupyter) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipykernel->jupyter) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: backcall in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: decorator in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: pickleshare in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.19.2)
# Requirement already satisfied: stack-data in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: typing-extensions in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->jupyter) (0.5.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.5)
# Requirement already satisfied: importlib-metadata>=4.8.3 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-client>=8.0.0->ipykernel->jupyter) (8.7.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (311)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipywidgets->jupyter) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from ipywidgets->jupyter) (3.0.16)
# Requirement already satisfied: beautifulsoup4 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from nbconvert->jupyter) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from nbconvert->jupyter) (3.1.6)
# Requirement already satisfied: jupyterlab-pygments in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from nbconvert->jupyter) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (4.25.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (0.27.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from notebook->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from notebook->jupyter) (2.28.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from notebook->jupyter) (4.5.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from notebook->jupyter) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (3.7.1)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.24.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (3.0.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (0.25.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (2.3.0)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (80.10.2)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (2.4.0)
# Requirement already satisfied: certifi in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<5,>=4.0.2->notebook->jupyter) (2022.12.7)
# Requirement already satisfied: httpcore==1.* in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<5,>=4.0.2->notebook->jupyter) (1.0.9)
# Requirement already satisfied: idna in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<5,>=4.0.2->notebook->jupyter) (3.4)
# Requirement already satisfied: sniffio in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<5,>=4.0.2->notebook->jupyter) (1.3.1)
# Requirement already satisfied: h11>=0.16 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<5,>=4.0.2->notebook->jupyter) (0.16.0)
# Requirement already satisfied: babel>=2.10 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.13.0)
# Requirement already satisfied: requests>=2.31 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.31.0)
# Requirement already satisfied: exceptiongroup in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (25.1.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (24.11.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.26.13)
# Requirement already satisfied: lark>=1.2.2 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.23)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.4.0)
# Requirement already satisfied: ipython_pygments_lexers in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from qtconsole->jupyter) (1.1.1)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from qtconsole->jupyter) (2.4.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
#
# ✅ All packages installed successfully!

# %%
import json
import os

db_path = os.path.join("data", "nutrition_db.json")

with open(db_path, "r") as f:
    nutrition_db = json.load(f)

# try
dish = "borsh"
print(f"{dish}: {nutrition_db[dish]['calories']} ккал, {nutrition_db[dish]['protein']} г белка")
# Out:
# borsh: 50 ккал, 1.5 г белка

# %%
import sys
# !{sys.executable} -m pip uninstall numpy pandas -y

# !{sys.executable} -m pip install numpy==1.23.5
# !{sys.executable} -m pip install pandas

print("completed")
# Out:
# Found existing installation: numpy 1.23.5
# Uninstalling numpy-1.23.5:
#   Successfully uninstalled numpy-1.23.5
# Found existing installation: pandas 2.3.3
# Uninstalling pandas-2.3.3:
#   Successfully uninstalled pandas-2.3.3
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\Professional\.conda\envs\kursach_env\Lib\site-packages\~-mpy'.
# You can safely remove it manually.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\Professional\.conda\envs\kursach_env\Lib\site-packages\~andas.libs'.
# You can safely remove it manually.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\Professional\.conda\envs\kursach_env\Lib\site-packages\~-ndas'.
# You can safely remove it manually.
# Collecting numpy==1.23.5
#   Using cached numpy-1.23.5-cp39-cp39-win_amd64.whl.metadata (2.3 kB)
# Using cached numpy-1.23.5-cp39-cp39-win_amd64.whl (14.7 MB)
# Installing collected packages: numpy
# Successfully installed numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# seaborn 0.12.2 requires pandas>=0.25, which is not installed.
# opencv-python-headless 4.13.0.90 requires numpy>=2; python_version >= "3.9", but you have numpy 1.23.5 which is incompatible.
# Collecting pandas
#   Using cached pandas-2.3.3-cp39-cp39-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\professional\.conda\envs\kursach_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.3-cp39-cp39-win_amd64.whl (11.4 MB)
# Installing collected packages: pandas
# Successfully installed pandas-2.3.3
# completed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import GradScaler, autocast
import torchvision.models as models
from torchvision import transforms, datasets

import numpy as np
import pandas as pd
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tqdm import tqdm
import random

# %%
#preparing
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

#gpu test
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 2060
# Memory: 6.4 GB

# %% [markdown]
# imports done, thank god all good right now, grinding model now

# %%
import shutil
import os

src_dir = "data"
dst_dir = "data_clean"

for class_name in os.listdir(src_dir):
    src_class = os.path.join(src_dir, class_name)
    if not os.path.isdir(src_class) or class_name.startswith("."):
        continue
    dst_class = os.path.join(dst_dir, class_name)
    os.makedirs(dst_class, exist_ok=True)
    for f in os.listdir(src_class):
        if f.lower().endswith((".jpg", ".jpeg", ".png")):
            shutil.copy(os.path.join(src_class, f), os.path.join(dst_class, f))

# %%
#transforms
transform=transforms.Compose({
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225])
})
data_dir='data_clean'
def is_image_file(path):
    valid_ext = (".jpg", ".jpeg", ".png")
    if ".ipynb_checkpoints" in path:
        return False
    return path.lower().endswith(valid_ext)

dataset=datasets.ImageFolder(root=data_dir, transform=transform, is_valid_file=is_image_file)
class_names=dataset.classes
num_classes=len(class_names)
print(f"Done {num_classes} classes")
# Out:
# Done 15 classes

# %%
all_images = [path for path, _ in dataset.imgs]
all_labels = [label for _, label in dataset.imgs]
train_imgs, temp_imgs, train_labels, temp_labels=train_test_split(all_images, all_labels, test_size=0.3, stratify=all_labels, random_state=42)
val_imgs, test_imgs, val_labels, test_labels=train_test_split(temp_imgs, temp_labels, test_size=1/3, stratify=temp_labels, random_state=42)
print(f"Train: {len(train_imgs)}, val: {len(val_imgs)}, test: {len(test_imgs)}")
# Out:
# Train: 1062, val: 304, test: 152

# %%
class CustomImageDataset():
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths=image_paths
        self.labels=labels
        self.transform=transform
    def __len__(self):
        return len(self.image_paths)
    def __getitem__(self, idx):
        img_path=self.image_paths[idx]
        label=self.labels[idx]
        image=Image.open(img_path).convert('RGB')
        if self.transform:
            image=self.transform(image)

        return image, label

batch_size=16
train_dataset=CustomImageDataset(train_imgs, train_labels, transform=transform)
val_dataset=CustomImageDataset(val_imgs, val_labels, transform=transform)
test_dataset=CustomImageDataset(test_imgs, test_labels, transform=transform)

train_loader=DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader=DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader=DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
#model resnet18 with diff last layer
from torchvision.models import resnet18, ResNet18_Weights

model=models.resnet18(weights=ResNet18_Weights.DEFAULT)
model.fc=nn.Linear(model.fc.in_features, num_classes)
model=model.to(device)

criterion=nn.CrossEntropyLoss()
optimizer=optim.Adam(model.parameters(), lr=1e-4)

# %%
def train_one_epo(model, loader):
    model.train()
    total_loss=0
    correct=0
    for images, labels in loader:
        images, labels=images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits, _ =model(images)
        loss=criterion(logits, labels)
        loss.backward()
        optimizer.step()

        total_loss+=loss.item()
        preds=torch.argmax(logits, dim=1)
        correct+=(preds==labels).sum().item()
    accuracy=correct/len(loader.dataset)
    return total_loss, accuracy

# %%
def validate(model, loader):
    model.eval()
    total_loss=0
    correct=0
    with torch.no_grad():
        for images, labels in loader:
            images, labels=images.to(device), labels.to(device)
            logits, _ =model(images)
            loss=criterion(logits, labels)
            total_loss+=loss.item()
            preds=torch.argmax(logits, dim=1)
            correct += (preds == labels).sum().item()
    accuracy=correct/len(loader.dataset)
    return total_loss, accurac

# %%
num_epochs=10

train_losses = []
train_accs = []
val_losses = []
val_accs = []

for epoch in range(num_epochs):
    train_loss, train_acc=train_one_epo(model, train_loader)
    val_loss, val_acc=validate(model, val_loader)

    train_losses.append(train_loss)
    train_accs.append(train_acc)
    val_losses.append(val_loss)
    val_accs.append(val_acc)
    
    print(f"Epoch {epoch+1}/{num_epochs}")
    print(f"Train loss: {train_loss:.4f}, Train acc: {train_acc:.4f}")
    print(f"Val   loss: {val_loss:.4f}, Val acc: {val_acc:.4f}")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

#loss
ax1.plot(range(1, num_epochs+1), train_losses, label='Train Loss', marker='o')
ax1.plot(range(1, num_epochs+1), val_losses, label='Val Loss', marker='s')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training and Validation Loss')
ax1.legend()
ax1.grid(True)

#accuracy
ax2.plot(range(1, num_epochs+1), train_accs, label='Train Accuracy', marker='o')
ax2.plot(range(1, num_epochs+1), val_accs, label='Val Accuracy', marker='s')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.set_title('Training and Validation Accuracy')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 9
#       6 val_accs = []
#       8 for epoch in range(num_epochs):
# ----> 9     train_loss, train_acc=train_one_epo(model, train_loader)
#      10     val_loss, val_acc=validate(model, val_loader)
#      12     train_losses.append(train_loss)
#
# Cell In[33], line 5, in train_one_epo(model, loader)
#       3 total_loss=0
#       4 correct=0
# ----> 5 for images, labels in loader:
#       6     images, labels=images.to(device), labels.to(device)
#       7     optimizer.zero_grad()
#
# File ~\.conda\envs\kursach_env\lib\site-packages\torch\utils\data\dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\.conda\envs\kursach_env\lib\site-packages\torch\utils\data\dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\.conda\envs\kursach_env\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~\.conda\envs\kursach_env\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[31], line 13, in CustomImageDataset.__getitem__(self, idx)
#      11 image=Image.open(img_path).convert('RGB')
#      12 if self.transform:
# ---> 13     image=self.transform(image)
#      15 return image, label
#
# File ~\.conda\envs\kursach_env\lib\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File ~\.conda\envs\kursach_env\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\.conda\envs\kursach_env\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\.conda\envs\kursach_env\lib\site-packages\torchvision\transforms\transforms.py:277, in Normalize.forward(self, tensor)
#     269 def forward(self, tensor: Tensor) -> Tensor:
#     270     """
#     271     Args:
#     272         tensor (Tensor): Tensor image to be normalized.
#    (...)
#     275         Tensor: Normalized Tensor image.
#     276     """
# --> 277     return F.normalize(tensor, self.mean, self.std, self.inplace)
#
# File ~\.conda\envs\kursach_env\lib\site-packages\torchvision\transforms\functional.py:361, in normalize(tensor, mean, std, inplace)
#     359     _log_api_usage_once(normalize)
#     360 if not isinstance(tensor, torch.Tensor):
# --> 361     raise TypeError(f"img should be Tensor Image. Got {type(tensor)}")
#     363 return F_t.normalize(tensor, mean=mean, std=std, inplace=inplace)
#
# TypeError: img should be Tensor Image. Got <class 'PIL.Image.Image'>
